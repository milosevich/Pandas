# %%
import pandas as pd # convention for import pandas

# %%
df = pd.read_csv('data/survey_results_public_top10.csv') # read csv file, path with '', like dataframes for visualize

# %%
df.head() # to see just first 5 rows
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.rename(columns={'OpenSourcer': 'open_sourcer'}) # rename column, change with dict, key:value is 'old_value':'new_value'
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                  open_sourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.head() # to see just first 5 rows, column name didn't change
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.rename(columns={'OpenSourcer': 'open_sourcer'}, inplace=True)  # we type 'inplace' to realy change df

# %%
df.head() # to see just first 5 rows, column name is changed
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                  open_sourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['Hobbyist'] # 'Hobbyist' has just 'yes' and 'no' values
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8    Yes
# 9    Yes
# Name: Hobbyist, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False}) # to make 'yes' to boolean True and 'No' to boolean False
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: Hobbyist, dtype: bool

# %%
df['Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8    Yes
# 9    Yes
# Name: Hobbyist, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No':False}) # when we are sure, realy change df['Hobbyist']

# %%
df['Hobbyist'] # it is changed
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: Hobbyist, dtype: bool
