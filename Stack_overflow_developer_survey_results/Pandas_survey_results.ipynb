# %%
import pandas as pd # convention for import pandas

# %%
df = pd.read_csv('data/survey_results_public_top10.csv', index_col='Respondent') # read csv file, set column name as index
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column') # read csv file, set column name as index

# %%
pd.set_option('display.max_columns', 85)  # change settings to see all columns
pd.set_option('display.max_rows', 85) # change settings to see all in schema_df

# %%
df.head(10) # to see first 10 rows
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False) # filtering Python

# %%
make_csv = df.loc[filt] # creating mask for data

# %%
make_csv.head(10)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# 9                   I am a developer by profession      Yes
# 10                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 4                                Never
# 5           Once a month or more often
# 8              Less than once per year
# 9           Once a month or more often
# 10          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
make_csv.to_csv('data/survey_results_public_top10_python.csv', header=True, index=True) # Write to csv
